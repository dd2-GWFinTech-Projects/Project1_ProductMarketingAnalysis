# %%
# System imports
import os
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import hvplot.pandas
import panel as pn
from pathlib import Path
from dotenv import load_dotenv
from panel.interact import interact
from panel import widgets
from string import digits
from numpy import array
import csv
import json
import numpy as np
import dateparser
import panel as pn
import matplotlib.ticker as tkr

plt.style.use('seaborn-white')


pn.extension()

# %matplotlib inline

# %%
# Local imports
import sys
sys.path.append("../lib2")

from Constants import Constants
from ProcessingTools import DateProcessingTools

# %%
# Construct the tools
debug_level = 0
constants = Constants()
tool_data_processing = DateProcessingTools(debug_level)

# %%
# Import all preprocessed data
atlas           = pd.read_pickle(constants.PREPROCESSED_ATLAS_FILE_PATH)
forecast        = pd.read_pickle(constants.PREPROCESSED_FORECAST_DATA_FILE_PATH)
revenue2020     = pd.read_pickle(constants.PREPROCESSED_REVENUE2020_FILE_PATH)
revenue2020A    = pd.read_pickle(constants.PREPROCESSED_REVENUE2020A_FILE_PATH)

# %%
atlas = atlas.sort_values(by='Invoice Date')

# %%
atlas.reset_index(inplace=True)
atlas
# Out:
#                                              Customers  Number of Users  \
# 0                           Louisiana Board of Regents           7050.0
# 1                             Emporia State University            250.0
# 2                            Morehead State University            100.0
# 3                       State University of NY Potsdam            500.0
# 4                       ST. Mary's College of Maryland             15.0
# ..                                                 ...              ...
# 695                             Modesto Junior College            200.0
# 696            University of North Carolina Wilmington            200.0
# 697                                   Brock University            350.0
# 698                          Holyoke Community College             50.0
# 699  University of South Carolina, College of Educa...            300.0
#
#                  Invoice Date  Invoice #  Year     Month  Invoice Amount  \
# 0   2015-03-20 00:00:00-04:00  ATLAS 315  2015     March         72000.0
# 1   2015-05-28 00:00:00-04:00      AJ501  2015       May          3500.0
# 2   2015-06-23 00:00:00-04:00      AJ502  2015      June          3500.0
# 3   2015-06-26 00:00:00-04:00      AJ503  2015      June          6500.0
# 4   2015-10-07 00:00:00-04:00      AJ504  2015   October           750.0
# ..                        ...        ...   ...       ...             ...
# 695 2020-12-08 00:00:00-05:00   NB120920  2020  December          1750.0
# 696 2020-12-08 00:00:00-05:00   NB12092B  2020  December          2000.0
# 697 2020-12-08 00:00:00-05:00   NB120820  2020  December          2500.0
# 698 2020-12-08 00:00:00-05:00  NB120920A  2020  December          1000.0
# 699 2020-12-09 00:00:00-05:00  NB120920C  2020  December          4500.0
#
#     Subscription 2021 Prediction Customers Status            Account Code   \
# 0         1 Year             NaN             Lost  4700-0-00-00000-18-0000
# 1         1 Year             NaN           Active  4700-0-00-00000-16-0000
# 2         1 Year             NaN           Active  4700-0-00-00000-17-0000
# 3         1 Year             NaN             Lost  4700-0-00-00000-32-0000
# 4         1 Year             NaN             Lost  4700-0-00-00000-20-0000
# ..           ...             ...              ...                      ...
# 695     6 Months      $1,750.00               New  4700-0-00-00000-00-0000
# 696       1 Year      $2,000.00            Active  4700-0-00-00000-00-0000
# 697     6 Months      $2,500.00               New  4700-0-00-00000-00-0000
# 698       1 Year        $500.00               New  4700-0-00-00000-00-0000
# 699       1 Year             NaN              New  4700-0-00-00000-00-0000
#
#                                                Address   State        Lat  \
# 0              1201 N 3rd St #6, Baton Rouge, LA 70802      LA  30.460190
# 1                     1 Kellogg Cir, Emporia, KS 66801      KS  38.392609
# 2              150 University Blvd, Morehead, KY 40351      KY  38.184921
# 3                 44 Pierrepont Ave, Potsdam, NY 13676      NY  44.663780
# 4            47645 College Dr, St Marys City, MD 20686      MD  38.190601
# ..                                                 ...     ...        ...
# 695                 435 College Ave, Modesto, CA 95350      CA  37.651310
# 696             601 S College Rd, Wilmington, NC 28403      NC  34.223991
# 697  1812 Sir Isaac Brock Way, St. Catharines, Onta...  Canada  43.118799
# 698           303 Homestead Avenue, Holyoke, MA  01040      MA  42.193910
# 699  820 Main Street, Wardlaw 221, Columbia, SC  29208      SC  33.996170
#
#            Long             Service Start               Service End  \
# 0    -91.188530 2015-03-18 00:00:00-04:00 2016-06-30 00:00:00-04:00
# 1    -96.181396 2015-06-01 00:00:00-04:00 2016-06-30 00:00:00-04:00
# 2    -83.434441 2015-06-10 00:00:00-04:00 2016-06-30 00:00:00-04:00
# 3    -74.978409 2015-06-01 00:00:00-04:00 2016-06-30 00:00:00-04:00
# 4    -76.426300 2015-10-05 00:00:00-04:00 2016-09-30 00:00:00-04:00
# ..          ...                       ...                       ...
# 695 -121.009726 2021-03-01 00:00:00-05:00 2021-08-31 00:00:00-04:00
# 696  -77.867764 2020-08-31 00:00:00-04:00 2021-08-31 00:00:00-04:00
# 697  -79.238508 2020-12-09 00:00:00-05:00 2021-05-31 00:00:00-04:00
# 698  -72.647450 2021-01-01 00:00:00-05:00 2021-12-31 00:00:00-05:00
# 699  -81.031200 2021-01-01 00:00:00-05:00 2021-12-31 00:00:00-05:00
#
#     Subscription Duration
# 0                365 days
# 1                365 days
# 2                365 days
# 3                365 days
# 4                365 days
# ..                    ...
# 695              180 days
# 696              365 days
# 697              180 days
# 698              365 days
# 699              365 days
#
# [700 rows x 18 columns]

# %%
atlas.dtypes
# Out:
# Customers                                          object
# Number of Users                                   float64
# Invoice Date             datetime64[ns, America/New_York]
# Invoice #                                          object
# Year                                                int64
# Month                                              object
# Invoice Amount                                    float64
# Subscription                                       object
# 2021 Prediction                                    object
# Customers Status                                   object
# Account Code                                       object
# Address                                            object
# State                                              object
# Lat                                               float64
# Long                                              float64
# Service Start            datetime64[ns, America/New_York]
# Service End              datetime64[ns, America/New_York]
# Subscription Duration                     timedelta64[ns]
# dtype: object

# %%
yearly_income = atlas.iloc[:, [0, 6, 4]]
yearly_income
# Out:
#                                              Customers  Invoice Amount  Year
# 0                           Louisiana Board of Regents         72000.0  2015
# 1                             Emporia State University          3500.0  2015
# 2                            Morehead State University          3500.0  2015
# 3                       State University of NY Potsdam          6500.0  2015
# 4                       ST. Mary's College of Maryland           750.0  2015
# ..                                                 ...             ...   ...
# 695                             Modesto Junior College          1750.0  2020
# 696            University of North Carolina Wilmington          2000.0  2020
# 697                                   Brock University          2500.0  2020
# 698                          Holyoke Community College          1000.0  2020
# 699  University of South Carolina, College of Educa...          4500.0  2020
#
# [700 rows x 3 columns]

# %%
 grp_yearly_income = yearly_income.groupby('Year').sum()
 grp_yearly_income.hvplot(
     figsize=(20,15), 
     kind='bar', 
     subplots=True, 
     title=('Total Sales by Year from 2015 to 2020'), 
     ylabel='Yearly Income', 
     xlabel='Total Number of Years',
     height=600,
     grid=True,
     width=1200).opts(yformatter='$%.0f', fontsize={'title': 25, 'labels': 20, 'xticks': 18, 'yticks': 18})
# Out:
# :Bars   [Year]   (Invoice Amount)

# %%
grp_yearly_income.hvplot(kind='table')
# Out:
# :Table   [Invoice Amount]

# %%
monthly_income = atlas.iloc[:, [0, 5, 6, 2]]
monthly_income.sort_values(by='Invoice Date')
monthly_income
# Out:
#                                              Customers     Month  \
# 0                           Louisiana Board of Regents     March
# 1                             Emporia State University       May
# 2                            Morehead State University      June
# 3                       State University of NY Potsdam      June
# 4                       ST. Mary's College of Maryland   October
# ..                                                 ...       ...
# 695                             Modesto Junior College  December
# 696            University of North Carolina Wilmington  December
# 697                                   Brock University  December
# 698                          Holyoke Community College  December
# 699  University of South Carolina, College of Educa...  December
#
#      Invoice Amount              Invoice Date
# 0           72000.0 2015-03-20 00:00:00-04:00
# 1            3500.0 2015-05-28 00:00:00-04:00
# 2            3500.0 2015-06-23 00:00:00-04:00
# 3            6500.0 2015-06-26 00:00:00-04:00
# 4             750.0 2015-10-07 00:00:00-04:00
# ..              ...                       ...
# 695          1750.0 2020-12-08 00:00:00-05:00
# 696          2000.0 2020-12-08 00:00:00-05:00
# 697          2500.0 2020-12-08 00:00:00-05:00
# 698          1000.0 2020-12-08 00:00:00-05:00
# 699          4500.0 2020-12-09 00:00:00-05:00
#
# [700 rows x 4 columns]

# %%
month_names = [ "January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December" ]
grp_monthly_income = monthly_income.groupby('Month').sum().reindex(month_names)
grp_monthly_income.hvplot(
    title='Total Sales by Month from 2015 to 2020', 
    ylabel='Monthly Income', 
    xlabel='Months', 
    figsize=(20,15), 
    kind='bar', 
    subplots=True, 
    height=800,
    grid=True,
    rot=45,
    width=1400).opts(yformatter='$%.0f', fontsize={'title': 25, 'labels': 20, 'xticks': 18, 'yticks': 18})
# Out:
# :Bars   [Month]   (Invoice Amount)

# %%
grp_monthly_income.hvplot(kind='table')
# Out:
# :Table   [Invoice Amount]

# %%
atlas.dtypes
# Out:
# Customers                                          object
# Number of Users                                   float64
# Invoice Date             datetime64[ns, America/New_York]
# Invoice #                                          object
# Year                                                int64
# Month                                              object
# Invoice Amount                                    float64
# Subscription                                       object
# 2021 Prediction                                    object
# Customers Status                                   object
# Account Code                                       object
# Address                                            object
# State                                              object
# Lat                                               float64
# Long                                              float64
# Service Start            datetime64[ns, America/New_York]
# Service End              datetime64[ns, America/New_York]
# Subscription Duration                     timedelta64[ns]
# dtype: object

# %%
subscription_income = atlas.iloc[:, [0, 1, 6, 7, 2]]
subscription_income.sort_values(by='Invoice Date')
# Out:
#                                              Customers  Number of Users  \
# 0                           Louisiana Board of Regents           7050.0
# 1                             Emporia State University            250.0
# 2                            Morehead State University            100.0
# 3                       State University of NY Potsdam            500.0
# 4                       ST. Mary's College of Maryland             15.0
# ..                                                 ...              ...
# 697                                   Brock University            350.0
# 698                          Holyoke Community College             50.0
# 695                             Modesto Junior College            200.0
# 696            University of North Carolina Wilmington            200.0
# 699  University of South Carolina, College of Educa...            300.0
#
#      Invoice Amount Subscription              Invoice Date
# 0           72000.0       1 Year 2015-03-20 00:00:00-04:00
# 1            3500.0       1 Year 2015-05-28 00:00:00-04:00
# 2            3500.0       1 Year 2015-06-23 00:00:00-04:00
# 3            6500.0       1 Year 2015-06-26 00:00:00-04:00
# 4             750.0       1 Year 2015-10-07 00:00:00-04:00
# ..              ...          ...                       ...
# 697          2500.0     6 Months 2020-12-08 00:00:00-05:00
# 698          1000.0       1 Year 2020-12-08 00:00:00-05:00
# 695          1750.0     6 Months 2020-12-08 00:00:00-05:00
# 696          2000.0       1 Year 2020-12-08 00:00:00-05:00
# 699          4500.0       1 Year 2020-12-09 00:00:00-05:00
#
# [700 rows x 5 columns]

# %%
customer_status = atlas.iloc[:, [0, 1, 6, 7, 2, 9]]
customer_status.sort_values(by='Invoice Date')
# Out:
#                                              Customers  Number of Users  \
# 0                           Louisiana Board of Regents           7050.0
# 1                             Emporia State University            250.0
# 2                            Morehead State University            100.0
# 3                       State University of NY Potsdam            500.0
# 4                       ST. Mary's College of Maryland             15.0
# ..                                                 ...              ...
# 697                                   Brock University            350.0
# 698                          Holyoke Community College             50.0
# 695                             Modesto Junior College            200.0
# 696            University of North Carolina Wilmington            200.0
# 699  University of South Carolina, College of Educa...            300.0
#
#      Invoice Amount Subscription              Invoice Date Customers Status
# 0           72000.0       1 Year 2015-03-20 00:00:00-04:00             Lost
# 1            3500.0       1 Year 2015-05-28 00:00:00-04:00           Active
# 2            3500.0       1 Year 2015-06-23 00:00:00-04:00           Active
# 3            6500.0       1 Year 2015-06-26 00:00:00-04:00             Lost
# 4             750.0       1 Year 2015-10-07 00:00:00-04:00             Lost
# ..              ...          ...                       ...              ...
# 697          2500.0     6 Months 2020-12-08 00:00:00-05:00              New
# 698          1000.0       1 Year 2020-12-08 00:00:00-05:00              New
# 695          1750.0     6 Months 2020-12-08 00:00:00-05:00              New
# 696          2000.0       1 Year 2020-12-08 00:00:00-05:00           Active
# 699          4500.0       1 Year 2020-12-09 00:00:00-05:00              New
#
# [700 rows x 6 columns]

# %%
subscription_income = atlas.iloc[:, [0, 6, 7, 2]]
subscription_income.sort_values(by='Invoice Date')
# Out:
#                                              Customers  Invoice Amount  \
# 0                           Louisiana Board of Regents         72000.0
# 1                             Emporia State University          3500.0
# 2                            Morehead State University          3500.0
# 3                       State University of NY Potsdam          6500.0
# 4                       ST. Mary's College of Maryland           750.0
# ..                                                 ...             ...
# 697                                   Brock University          2500.0
# 698                          Holyoke Community College          1000.0
# 695                             Modesto Junior College          1750.0
# 696            University of North Carolina Wilmington          2000.0
# 699  University of South Carolina, College of Educa...          4500.0
#
#     Subscription              Invoice Date
# 0         1 Year 2015-03-20 00:00:00-04:00
# 1         1 Year 2015-05-28 00:00:00-04:00
# 2         1 Year 2015-06-23 00:00:00-04:00
# 3         1 Year 2015-06-26 00:00:00-04:00
# 4         1 Year 2015-10-07 00:00:00-04:00
# ..           ...                       ...
# 697     6 Months 2020-12-08 00:00:00-05:00
# 698       1 Year 2020-12-08 00:00:00-05:00
# 695     6 Months 2020-12-08 00:00:00-05:00
# 696       1 Year 2020-12-08 00:00:00-05:00
# 699       1 Year 2020-12-09 00:00:00-05:00
#
# [700 rows x 4 columns]

# %%
yearly_income = atlas.iloc[:, [0, 6, 4, 5]]
yearly_income
# Out:
#                                              Customers  Invoice Amount  Year  \
# 0                           Louisiana Board of Regents         72000.0  2015
# 1                             Emporia State University          3500.0  2015
# 2                            Morehead State University          3500.0  2015
# 3                       State University of NY Potsdam          6500.0  2015
# 4                       ST. Mary's College of Maryland           750.0  2015
# ..                                                 ...             ...   ...
# 695                             Modesto Junior College          1750.0  2020
# 696            University of North Carolina Wilmington          2000.0  2020
# 697                                   Brock University          2500.0  2020
# 698                          Holyoke Community College          1000.0  2020
# 699  University of South Carolina, College of Educa...          4500.0  2020
#
#         Month
# 0       March
# 1         May
# 2        June
# 3        June
# 4     October
# ..        ...
# 695  December
# 696  December
# 697  December
# 698  December
# 699  December
#
# [700 rows x 4 columns]

# %%
new_customers = atlas.iloc[:, [0, 2, 6, 9]]
new_customers
# Out:
#                                              Customers  \
# 0                           Louisiana Board of Regents
# 1                             Emporia State University
# 2                            Morehead State University
# 3                       State University of NY Potsdam
# 4                       ST. Mary's College of Maryland
# ..                                                 ...
# 695                             Modesto Junior College
# 696            University of North Carolina Wilmington
# 697                                   Brock University
# 698                          Holyoke Community College
# 699  University of South Carolina, College of Educa...
#
#                  Invoice Date  Invoice Amount Customers Status
# 0   2015-03-20 00:00:00-04:00         72000.0             Lost
# 1   2015-05-28 00:00:00-04:00          3500.0           Active
# 2   2015-06-23 00:00:00-04:00          3500.0           Active
# 3   2015-06-26 00:00:00-04:00          6500.0             Lost
# 4   2015-10-07 00:00:00-04:00           750.0             Lost
# ..                        ...             ...              ...
# 695 2020-12-08 00:00:00-05:00          1750.0              New
# 696 2020-12-08 00:00:00-05:00          2000.0           Active
# 697 2020-12-08 00:00:00-05:00          2500.0              New
# 698 2020-12-08 00:00:00-05:00          1000.0              New
# 699 2020-12-09 00:00:00-05:00          4500.0              New
#
# [700 rows x 4 columns]

# %%
Group_Customers = new_customers.groupby(['Customers']).sum()
TOP_10_Highest = Group_Customers.sort_values(by="Invoice Amount", ascending=False).head(10)
TOP_10_Highest = TOP_10_Highest.reset_index()

# %%
# Plotting the data from the top 10 Highest Customers
TOP_10_Highest.hvplot.bar(
    x="Customers", 
    y="Invoice Amount", 
    xlabel = "Highest Paying Customers",
    ylabel = "Total Sales",
    title="Top 10 Highest Paying Customers of All Time", 
    figsize=(20,15), 
    subplots=True, 
    height=800,
    grid=True,
    rot=45,
    width=1400).opts(yformatter='$%.0f', fontsize={'title': 25, 'labels': 20, 'xticks': 18, 'yticks': 18})
# Out:
# :Bars   [Customers]   (Invoice Amount)

# %%
TOP_10_Highest.hvplot.table()
# Out:
# :Table   [Customers,Invoice Amount]

# %%
Group_Customers_2 = new_customers.groupby(['Customers']).sum()
TOP_10_Lowest = Group_Customers_2.sort_values(by="Invoice Amount", ascending=True).head(10)
TOP_10_Lowest = TOP_10_Lowest.reset_index()

# %%
# Plotting the data from the top 10 Lowest Customers
TOP_10_Lowest.hvplot.bar(
    x="Customers", 
    y="Invoice Amount", 
    xlabel = "Lowest Paying Customers",
    ylabel = "Total Sales",
    title="Top 10 Lowest Paying Customers of All Time", 
    figsize=(20,15), 
    subplots=True, 
    height=800,
    grid=True,
    rot=45,
    width=1400).opts(yformatter='$%.0f', fontsize={'title': 25, 'labels': 20, 'xticks': 18, 'yticks': 18})
# Out:
# :Bars   [Customers]   (Invoice Amount)

# %%
TOP_10_Lowest.hvplot.table()
# Out:
# :Table   [Customers,Invoice Amount]

# %%
new_customers = atlas.iloc[:, [0, 2, 6, 9]]
new_customers
# Out:
#                                              Customers  \
# 0                           Louisiana Board of Regents
# 1                             Emporia State University
# 2                            Morehead State University
# 3                       State University of NY Potsdam
# 4                       ST. Mary's College of Maryland
# ..                                                 ...
# 695                             Modesto Junior College
# 696            University of North Carolina Wilmington
# 697                                   Brock University
# 698                          Holyoke Community College
# 699  University of South Carolina, College of Educa...
#
#                  Invoice Date  Invoice Amount Customers Status
# 0   2015-03-20 00:00:00-04:00         72000.0             Lost
# 1   2015-05-28 00:00:00-04:00          3500.0           Active
# 2   2015-06-23 00:00:00-04:00          3500.0           Active
# 3   2015-06-26 00:00:00-04:00          6500.0             Lost
# 4   2015-10-07 00:00:00-04:00           750.0             Lost
# ..                        ...             ...              ...
# 695 2020-12-08 00:00:00-05:00          1750.0              New
# 696 2020-12-08 00:00:00-05:00          2000.0           Active
# 697 2020-12-08 00:00:00-05:00          2500.0              New
# 698 2020-12-08 00:00:00-05:00          1000.0              New
# 699 2020-12-09 00:00:00-05:00          4500.0              New
#
# [700 rows x 4 columns]

# %%
Group_Customers_Status = new_customers.groupby(['Customers Status', 'Customers']).count()
Group_Customers_Status = Group_Customers_Status.reset_index()
Group_Customers_Status
# Out:
#     Customers Status                                    Customers  \
# 0             Active  Alabama A&M University-College of Education
# 1             Active                      Albertus Magnus College
# 2             Active                American College of Education
# 3             Active                           Augusta University
# 4             Active                 Austin Peay State University
# ..               ...                                          ...
# 387              New                   William Baptist University
# 388              New                  William Paterson University
# 389              New                           Wingate University
# 390              New               Winston-Salem State University
# 391              New                        Yakima Valley College
#
#      Invoice Date  Invoice Amount
# 0               1               1
# 1               1               1
# 2               1               1
# 3               7               7
# 4               4               4
# ..            ...             ...
# 387             1               1
# 388             1               1
# 389             1               1
# 390             1               1
# 391             1               1
#
# [392 rows x 4 columns]

# %%
New_Customers_2020 = Group_Customers_Status.loc[:, 'New']
New_Customers_2020
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.conda/envs/pyvizenv/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'New'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-76c35f38693d> in <module>
# ----> 1 New_Customers_2020 = Group_Customers_Status.loc[:, 'New']
#       2 New_Customers_2020
#
# ~/.conda/envs/pyvizenv/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1760                 except (KeyError, IndexError, AttributeError):
#    1761                     pass
# -> 1762             return self._getitem_tuple(key)
#    1763         else:
#    1764             # we by definition only have the 0th axis
#
# ~/.conda/envs/pyvizenv/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1270     def _getitem_tuple(self, tup: Tuple):
#    1271         try:
# -> 1272             return self._getitem_lowerdim(tup)
#    1273         except IndexingError:
#    1274             pass
#
# ~/.conda/envs/pyvizenv/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#    1387         for i, key in enumerate(tup):
#    1388             if is_label_like(key) or isinstance(key, tuple):
# -> 1389                 section = self._getitem_axis(key, axis=i)
#    1390
#    1391                 # we have yielded a scalar ?
#
# ~/.conda/envs/pyvizenv/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1963         # fall thru to straight lookup
#    1964         self._validate_key(key, axis)
# -> 1965         return self._get_label(key, axis=axis)
#    1966
#    1967
#
# ~/.conda/envs/pyvizenv/lib/python3.8/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     623             raise IndexingError("no slices here, handle elsewhere")
#     624
# --> 625         return self.obj._xs(label, axis=axis)
#     626
#     627     def _get_loc(self, key: int, axis: int):
#
# ~/.conda/envs/pyvizenv/lib/python3.8/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3527
#    3528         if axis == 1:
# -> 3529             return self[key]
#    3530
#    3531         self._consolidate_inplace()
#
# ~/.conda/envs/pyvizenv/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~/.conda/envs/pyvizenv/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'New'

# %%
New_Customers.hvplot()

# %%
total_customers.sort_values(by='Invoice Amount', ascending=False)
total_customers.tail()

# %%
total_customers.plot()

# %%
start_to_2019 = past_years.loc[[2015, 2016, 2017, 2018, 2019]]
start_to_2019

# %%
grp_past_years = start_to_2019.groupby('Year').sum()
grp_past_years.hvplot(figsize=(20,15), rot=90, kind='bar', subplots=True).opts(yformatter='%d', title='Average of Sales from 2015 to 2019', ylabel='Income Each Year', xlabel='Total Number of Years', height=600, width=1200)

# %%
monthly_income_15_19 = atlas.iloc[:, [0, 6, 4, 5]]
monthly_income_15_19

# %%
past_years_months = monthly_income_15_19.groupby(['Year', 'Month']).sum()
past_years_months

# %%
months_start_to_2019 = past_years_months.loc[[2015, 2016, 2017, 2018, 2019]]
months_start_to_2019

# %%
month_names = [ "January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December" ]
grp_past_months_start_to_2019 = months_start_to_2019.groupby('Month').mean().reindex(month_names)
grp_past_months_start_to_2019_plt = grp_past_months_start_to_2019.hvplot(figsize=(20,15), kind='area', subplots=True).opts(yformatter='%d', title='Average Monthly Sales from 2015 to 2019 VS. Year 2020', ylabel='Income Each Month', xlabel='Months', height=600, width=1200)
grp_past_months_start_to_2019_plt

# %%
months_2020 = past_years_months.loc[[2020]]
months_2020

# %%
month_names = [ "January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December" ]
grp_past_months_2020 = months_2020.groupby('Month').mean().reindex(month_names)
grp_past_months_2020_plt = grp_past_months_2020.hvplot(figsize=(20,15), kind='area', subplots=True).opts(yformatter='%d', title='Average Monthly Sales from 2015 to 2019 VS. Year 2020', ylabel='Income Each Month', xlabel='Months', height=600, width=1200)
grp_past_months_2020_plt

# %%
compare_15_19_t0_20 = grp_past_months_2020_plt * grp_past_months_start_to_2019_plt
compare_15_19_t0_20

# %%
atlas.dtypes

# %%
customer_status = atlas.iloc[:, [0, 1, 4, 6, 9]]
customer_status

# %%
past_years_months = monthly_income_15_19.groupby(['Year', 'Month']).sum()
past_years_months

# %%
months_2020 = past_years_months.loc[[2020]]
months_2020

# %%
month_names = [ "January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December" ]
grp_past_months_2020 = months_2020.groupby('Month').mean().reindex(month_names)
grp_past_months_2020_plt = grp_past_months_2020.hvplot(figsize=(20,15), rot=90, kind='bar', subplots=True).opts(yformatter='%d', title='Average Monthly Sales in 2020', ylabel='Income Each Month', xlabel='Months', height=600, width=1200)
grp_past_months_2020_plt

# %%
daily_income = atlas.iloc[:, [2, 6]]
daily_income

# %%
daily_income.describe()

# %%
atlas.dtypes

# %%
daily_income = atlas.iloc[:, [0, 6, 9, 4]]
daily_income

# %%
multi_group = daily_income.groupby(['Customers','Customers Status'])['Customers Status'].count()
multi_group

# %%
new_customers = multi_group.loc[['New']].count()
new_customers

# %%
multi_group.hvplot()

# %%
# Calculate the mean values for each neighborhood
#rankings_pd.rename(columns = {'test':'TEST', 'odi':'ODI', 
#                              't20':'T20'}, inplace = True) 

#atlas2.columns = ["Customers", "Lat", "Long"]

total_data = atlas.loc[:, ["Number of Users", "Invoice Amount"]].groupby(["Customers"]).sum()
# total_data.dropna(inplace=True)
total_data

atlas_with_totals = pd.concat([atlas.drop(columns=["Number of Users", "Invoice Amount"]), total_data], axis="columns", join="inner")
atlas_with_totals.head(5)

# %%
atlas_with_totals.dtypes

# %%
atlas_with_totals.count()

# %%
atlas_with_totals.set_index(pd.to_datetime(atlas_with_totals['Invoice Date'], infer_datetime_format=True), inplace=True)
atlas_with_totals["Invoice Amount"].plot(kind='bar', figsize=(20,10))

# %%
atlas_with_totals.describe()

# %%
atlas_with_totals.iloc[0]

# %%
data = atlas_with_totals.iloc[:, [0,2,5,11,12]]
data.head()

# %%
data.drop(columns=['Invoice Date', 'Subscription', 'Number of Users'], inplace=True)
data

# %%
data.sort_values("Invoice Amount", ascending=False)
data.plot()

# %%
data.groupby(by='State').sum()
data

# %%
data = data.sort_values(by='Invoice Date', ascending=False)

# %%
data.plot(figsize=(20,15))

# %%
data.tail()

# %%
data.drop(columns=['State'], inplace=True)
data

# %%
daily_returns = (data - data.shift(1)) / data.shift(1)
daily_returns.head()

# %%
daily_returns = data.pct_change()
daily_returns.head()

# %%
daily_returns.plot(figsize=(10,5))

# %%
# Calculate the cumulative returns using the 'cumprod()' function
cumulative_returns = (1 + daily_returns).cumprod()
cumulative_returns.head()

# %%
# Plot the daily returns of the S&P 500 over the last 5 years
cumulative_returns.plot(figsize=(10,5))
